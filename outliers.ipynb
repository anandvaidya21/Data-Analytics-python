# %%
print("HELLO")
# Out:
# HELLO

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("house_purchased.csv")

# %%
df.sample(3)
# Out:
#        price  area  purchased
# 379  3633000  3520          0
# 486  2870000  6000          0
# 369  3675000  3600          1

# %%
#finding the IQR
p25 = df['price'].quantile(0.25)
p75 = df['price'].quantile(0.75)

# %%
IQR = p75-p25
print(IQR)
# Out:
# 2310000.0

# %%
upper_limit = p75+ 1.5*IQR
lower_limit = p25- 1.5*IQR

# %%
print(upper_limit,lower_limit)
# Out:
# 9205000.0 -35000.0
